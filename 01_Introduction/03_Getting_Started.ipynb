# %%
import pandas

# %%
data_set = {
    'cars': ["BMW", "Volvo", "Ford"],
    'passings': [3, 7, 2]
}
var = pandas.DataFrame(data_set)
print(var)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd
data_set = {
    'cars': ["BMW", "Volvo", "Ford"],
    'passings': [3, 7, 2]
}
var = pd.DataFrame(data_set)
print(var)
# Out:
#     cars  passings
# 0    BMW         3
# 1  Volvo         7
# 2   Ford         2

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2
